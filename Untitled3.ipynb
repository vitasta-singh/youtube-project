# %%
pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (2.111.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (2.25.2)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (2.15.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.21.12)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

from googleapiclient.discovery import build

# %%
def Api_connect():
    Api_Id = 'AIzaSyA8Kh778fHg0uqbVaWhutpFCkIvaFj_9OE'  #api key

    api_service_name = 'youtube'
    api_version = 'v3'

    youtube = build(api_service_name, api_version, developerKey=Api_Id)

    return youtube

# %%
youtube = Api_connect()

# %%
api_key = 'AIzaSyA8Kh778fHg0uqbVaWhutpFCkIvaFj_9OE'
           # api key
youtube = build('youtube', 'v3', developerKey=api_key) 
    
def channel_details(youtube,channel_id):
    
        
    
    response = youtube.channels().list(id=channel_id, part='snippet,statistics,contentDetails')
    channel_data = response.execute()
    for i in range(0,len(channel_data['items'])):
        details = dict(channel_name = channel_data['items'][i]['snippet']['title'],
        channel_ID= channel_data['items'][i]['id'],               
        channel_description = channel_data['items'][i]['snippet']['description'],
        channel_plyt = channel_data['items'][i]['snippet']['publishedAt'],
        playlists = channel_data['items'][i]['contentDetails']['relatedPlaylists']['uploads'],
        channel_scount= channel_data['items'][i]['statistics']['subscriberCount'],
        channel_vcount= channel_data['items'][i]['statistics']['videoCount'],
        channel_views= channel_data['items'][i]['statistics']['viewCount'])
        
    return details

# %%
def get_video_ids(youtube,channel_id):
        video_id = []
        response = youtube.channels().list(id=channel_id, part='contentDetails')
        channel_data = response.execute()
        playlists= channel_data['items'][0]['contentDetails']['relatedPlaylists']['uploads']
        npt=True
        next_page_token = None
        
        while npt:
            request = youtube.playlistItems().list(part='contentDetails',playlistId=playlists,maxResults=50,pageToken=next_page_token)
            response_ = request.execute()

                # Get video IDs
            for item in response_['items']:
                video_id.append(item['contentDetails']['videoId'])
                # Check if there are more pages
            next_page_token = response_.get('nextPageToken')
            if not next_page_token:
                npt=False

        return video_id

# %%
def get_video_details(youtube,video_id):
    all_video_stats=[]
    for video_ids in video_id:
        request = youtube.videos().list(part='snippet,statistics,contentDetails', id=video_ids)

        response= request.execute()
        for video in range (len(response['items'])):
            video_stats = dict(vID=response['items'][video]['id'],
                               channeltitle=response['items'][video]['snippet']['channelTitle'],
                               channel_IDS=response['items'][video]['snippet']['channelId'],
                               videotitle=response['items'][video]['snippet']['title'],
                               videdescript=response['items'][video]['snippet']['description'],
                               vTags=','.join(response['items'][video]['snippet'].get('tags',[])),
                               videopublish=response['items'][video]['snippet']['publishedAt'],
                               videduration= response['items'][video]['contentDetails']['duration'],
                               videolikecount=response['items'][video]['statistics'].get('likeCount',0),
                               videocommcount=response['items'][video]['statistics'].get('commentCount',0),
                               videocaption=response['items'][video]['contentDetails']['caption'],
                               videothumb=response['items'][video]['snippet']['thumbnails']['default']['url'],
                               videoVIEWcount=response['items'][video]['statistics']['viewCount'])
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
def commdetails(youtube,video_id):
    c=[]
    for vi_deo_id in video_id:
        try:
            request = youtube.commentThreads().list(part="snippet",maxResults=25, videoId=vi_deo_id)
            response = request.execute()
            for commentss in response['items']:
                comm_stats = dict(videoI=commentss['snippet']['topLevelComment']['snippet']['videoId'], commid=commentss['snippet']['topLevelComment']['id'],commpublish=commentss['snippet']['topLevelComment']['snippet']['publishedAt'],commauthor=commentss['snippet']['topLevelComment']['snippet']['authorDisplayName'], 
                                  commtxt=commentss['snippet']['topLevelComment']['snippet']['textDisplay'])
                c.append( comm_stats)
        except:
            pass
    
    return c

# %%
from pymongo import MongoClient
client=MongoClient("mongodb://localhost:27017/")

# %%
db=client['youtube_DATA_project']

# %%
def main(channel_id):
    channels=channel_details(youtube,channel_id)
    videooids=get_video_ids(youtube,channel_id)
    videodetails=get_video_details(youtube,videooids)
    commentdetail=commdetails(youtube,videooids)
    newdb=db['channels']
    
    newdb.insert_one({'channel_info':channels, 'video_details':videodetails, 'comment_details':commentdetail})
    return "successful data to mongo"

# %%
main("UCj_eYKbmUXvsbDssD3pQBXA")
# Out:
# 'successful data to mongo'

# %%
client.list_database_names()
# Out:
# ['DS',
#  'GUVI',
#  'admin',
#  'blogs',
#  'comments',
#  'config',
#  'datatype',
#  'local',
#  'relationship',
#  'restaurant',
#  'youtube_DATA_project']

# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (8.2.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in c:\users\dheeraj\appdata\local\programs\python\python312\lib\site-packages (from mysql-connector-python) (4.21.12)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Chunnu@123")
print(mydb)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x00000195A87A7020>

# %%
mycursor=mydb.cursor()

# %%
mycursor.execute("CREATE DATABASE Youtube_harvesting_data")

# %%
mycursor.execute("SHOW DATABASES")
for x in mycursor:
    print(x)
# Out:
# ('information_schema',)
# ('mydatabase',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('xyz',)
# ('youtube',)
# ('youtube_harvesting_data',)

# %%
mycursor.execute("use youtube_harvesting_data")

# %%
import streamlit as st
import pandas as pd

# %%
def channels_table():
   mydb = mysql.connector.connect(host="localhost",user="root",password="Chunnu@123",database="youtube_harvesting_data")
   mycursor=mydb.cursor()

   try:
      create_query='''CREATE TABLE  if not exists channels(ch_id VARCHAR(255) primary key, ch_name VARCHAR(255), ch_description TEXT,ch_play_id VARCHAR(80), ch_v_count bigint, ch_sub_count bigint,ch_view_count bigint,ch_played VARCHAR(100))'''
      mycursor.execute(create_query)
      mydb.commit() 
   
    
   except:
      print("table already exist")
   channel_list=[]
   db=client['youtube_DATA_project']
   newdb=db['channels']
   for chdata in newdb.find({},{"_id":0,"channel_info":1}):
      channel_list.append(chdata["channel_info"])
   df=pd.DataFrame(channel_list)

   for index,row in df.iterrows():
      insert_query='''insert into channels(ch_id,ch_name,ch_description,ch_play_id,ch_v_count,ch_sub_count,ch_view_count,ch_played)
      values(%s,%s,%s,%s,%s,%s,%s,%s)'''
      values=(row['channel_ID'],row['channel_name'],row['channel_description'],row['playlists'], row['channel_vcount'],row['channel_scount'],row['channel_views'],row['channel_plyt'])
      try:
         mycursor.execute(insert_query,values)
         mydb.commit()
      except:
         print("already")

# %%
channels_table()
# Out:
# already
# already
# already
# already
# already
# already

# %%
db=client['youtube_DATA_project']
newdb=db['channels']
for chdata in newdb.find({},{"_id":0,"channel_info":1}):
    print(chdata["channel_info"])
# Out:
# {'channel_name': 'Dadi Ki Rasoi', 'channel_ID': 'UC0GGy2O7TE_gyTzyrsN5hYQ', 'channel_description': 'Khana Banaye Aur Sabko Khilaye ❤️', 'channel_plyt': '2023-09-11T09:33:17.691521Z', 'playlists': 'UU0GGy2O7TE_gyTzyrsN5hYQ', 'channel_scount': '315000', 'channel_vcount': '67', 'channel_views': '28276669'}
# {'channel_name': 'Streamlit', 'channel_ID': 'UC3LD42rjj-Owtxsa6PwGU5Q', 'channel_description': 'Streamlit is a faster way to create and share data apps. Streamlit’s open-source app framework enables data scientists and machine learning engineers to create beautiful, performant apps in only a few hours! \n\nWant to test it out? \nIn a terminal: $ pip install streamlit', 'channel_plyt': '2019-09-30T21:53:52Z', 'playlists': 'UU3LD42rjj-Owtxsa6PwGU5Q', 'channel_scount': '11700', 'channel_vcount': '50', 'channel_views': '555526'}
# {'channel_name': 'Rishabh Mishra', 'channel_ID': 'UC3rY5HOgbBvGmq7RnDfwF7A', 'channel_description': 'Education, Jobs, Career + College Tips 😉\n\nHope you get best out of it and helps you to grow professionally and personally. \n\nFor any queries, you can reach to out to my Instagram Account- rishabhnmishra.\n', 'channel_plyt': '2022-02-12T14:28:29.641872Z', 'playlists': 'UU3rY5HOgbBvGmq7RnDfwF7A', 'channel_scount': '179000', 'channel_vcount': '82', 'channel_views': '10153417'}
# {'channel_name': 'Analyst Adithya', 'channel_ID': 'UC61Y04JVLkByFRv1K3V-KGQ', 'channel_description': 'I am Vyas Adithya and I have more than 6 years of experience in business intelligence, data analytics and marketing analytics.\n\nI also secured the Amazon Business Analyst internship offer in the EU headquarters in Luxembourg.\n\nI have previously worked for e-commerce companies in Mexico City and Berlin and have used SQL,Power BI, Python, Microsoft Excel on a regular basis.\n\nI have trained more than 300 people on tech tools previously and helped them secure internships in BI and analyst roles in Berlin and other German cities.\n', 'channel_plyt': '2022-01-26T09:02:17.431384Z', 'playlists': 'UU61Y04JVLkByFRv1K3V-KGQ', 'channel_scount': '6580', 'channel_vcount': '194', 'channel_views': '131771'}
# {'channel_name': 'rjkarishma', 'channel_ID': 'UCJvE3uJFyBS1WhL1Tou85Hg', 'channel_description': '', 'channel_plyt': '2013-01-02T16:59:44Z', 'playlists': 'UUJvE3uJFyBS1WhL1Tou85Hg', 'channel_scount': '6410000', 'channel_vcount': '239', 'channel_views': '3494981527'}
# {'channel_name': 'Nature Is Love', 'channel_ID': 'UC3aTgjd4_ocJuhqSXlcvkNg', 'channel_description': '', 'channel_plyt': '2022-07-27T07:04:47.108337Z', 'playlists': 'UU3aTgjd4_ocJuhqSXlcvkNg', 'channel_scount': '23', 'channel_vcount': '10', 'channel_views': '1113'}
# {'channel_name': 'Data Science Tamil', 'channel_ID': 'UCuI5XcJYynHa5k_lqDzAgwQ', 'channel_description': 'Dear Brothers and Sisters,\n\n         (Please clarify your doubts in Project doubt clarification session)\n          Really SORRY for the INCONVENIENCE.\n', 'channel_plyt': '2023-10-12T13:09:46.068033Z', 'playlists': 'UUuI5XcJYynHa5k_lqDzAgwQ', 'channel_scount': '369', 'channel_vcount': '21', 'channel_views': '38344'}
# {'channel_name': 'techTFQ', 'channel_ID': 'UCnz-ZXXER4jOvuED5trXfEA', 'channel_description': 'Hi, I am Thoufiq! On this channel, I teach SQL, Python and Database concepts in the field of Data Analytics and Data Science in the most simplest manner possible. If this excites you then do consider subscribing.\n\nYou will also find videos covering interview questions and also videos where I provide career guidance in the field of Data Analytics and Data Science which should help you find your dream job.\n\nI aim to make techTFQ a go to YouTube channel for anyone learning SQL, Python and Databases in the field of Data Analytics and Data Science.\n\nThank you for begin here :)\n', 'channel_plyt': '2020-06-13T05:20:37.182391Z', 'playlists': 'UUnz-ZXXER4jOvuED5trXfEA', 'channel_scount': '258000', 'channel_vcount': '100', 'channel_views': '13623202'}
# {'channel_name': 'Barkha Singh', 'channel_ID': 'UCKbGPpepdFDgJ0FMM90aI7g', 'channel_description': "Hey lovelies! \n\nYou've known me as Gia, Surbhi, Jyoti and and a whole lot of other characters I've lived. \nBut now it's about time you got to know the glorious mess that I am, so I started my YouTube channel. \n\nSo…….. HI! :D \n(yes I'm super excited about this) \n\nInstagram - https://www.instagram.com/barkhasingh0308/\nFacebook - https://www.facebook.com/officialbarkhasingh0308/", 'channel_plyt': '2018-01-18T08:19:17Z', 'playlists': 'UUKbGPpepdFDgJ0FMM90aI7g', 'channel_scount': '481000', 'channel_vcount': '78', 'channel_views': '88115773'}
# {'channel_name': 'Kusha Kapila', 'channel_ID': 'UCj_eYKbmUXvsbDssD3pQBXA', 'channel_description': 'THAT SOUTH DELHI GIRL', 'channel_plyt': '2011-10-07T06:09:18Z', 'playlists': 'UUj_eYKbmUXvsbDssD3pQBXA', 'channel_scount': '1050000', 'channel_vcount': '272', 'channel_views': '440580264'}

# %%
for index,row in df.iterrows():
      insert_query='''insert into channels(ch_id,ch_name,ch_description,ch_play_id,ch_v_count,ch_sub_count,ch_view_count,ch_played)
      values(%s,%s,%s,%s,%s,%s,%s,%s)'''
      values=(row['channel_ID'],row['channel_name'],row['channel_description'],row['playlists'], row['channel_vcount'],row['channel_scount'],row['channel_views'],row['channel_plyt'])
      try:
         mycursor.execute(insert_query,values)
         mydb.commit()
      except:
         print("already")
# Out:
# already

# %%
channels_table()
# Out:
# already
# already
# already
# already
# already
# already
# already
# already
# already
# already

# %%
channel_list=[]
db=client['youtube_DATA_project']
newdb=db['channels']
for chdata in newdb.find({},{"_id":0,"channel_info":1}):
   channel_list.append(chdata["channel_info"])
df=pd.DataFrame(channel_list)
print(df)
# Out:
#          channel_name                channel_ID  \
# 0       Dadi Ki Rasoi  UC0GGy2O7TE_gyTzyrsN5hYQ
# 1           Streamlit  UC3LD42rjj-Owtxsa6PwGU5Q
# 2      Rishabh Mishra  UC3rY5HOgbBvGmq7RnDfwF7A
# 3     Analyst Adithya  UC61Y04JVLkByFRv1K3V-KGQ
# 4          rjkarishma  UCJvE3uJFyBS1WhL1Tou85Hg
# 5      Nature Is Love  UC3aTgjd4_ocJuhqSXlcvkNg
# 6  Data Science Tamil  UCuI5XcJYynHa5k_lqDzAgwQ
# 7             techTFQ  UCnz-ZXXER4jOvuED5trXfEA
# 8        Barkha Singh  UCKbGPpepdFDgJ0FMM90aI7g
# 9        Kusha Kapila  UCj_eYKbmUXvsbDssD3pQBXA
#
#                                  channel_description  \
# 0                  Khana Banaye Aur Sabko Khilaye ❤️
# 1  Streamlit is a faster way to create and share ...
# 2  Education, Jobs, Career + College Tips 😉\n\nHo...
# 3  I am Vyas Adithya and I have more than 6 years...
# 4
# 5
# 6  Dear Brothers and Sisters,\n\n         (Please...
# 7  Hi, I am Thoufiq! On this channel, I teach SQL...
# 8  Hey lovelies! \n\nYou've known me as Gia, Surb...
# 9                              THAT SOUTH DELHI GIRL
#
#                   channel_plyt                 playlists channel_scount  \
# 0  2023-09-11T09:33:17.691521Z  UU0GGy2O7TE_gyTzyrsN5hYQ         315000
# 1         2019-09-30T21:53:52Z  UU3LD42rjj-Owtxsa6PwGU5Q          11700
# 2  2022-02-12T14:28:29.641872Z  UU3rY5HOgbBvGmq7RnDfwF7A         179000
# 3  2022-01-26T09:02:17.431384Z  UU61Y04JVLkByFRv1K3V-KGQ           6580
# 4         2013-01-02T16:59:44Z  UUJvE3uJFyBS1WhL1Tou85Hg        6410000
# 5  2022-07-27T07:04:47.108337Z  UU3aTgjd4_ocJuhqSXlcvkNg             23
# 6  2023-10-12T13:09:46.068033Z  UUuI5XcJYynHa5k_lqDzAgwQ            369
# 7  2020-06-13T05:20:37.182391Z  UUnz-ZXXER4jOvuED5trXfEA         258000
# 8         2018-01-18T08:19:17Z  UUKbGPpepdFDgJ0FMM90aI7g         481000
# 9         2011-10-07T06:09:18Z  UUj_eYKbmUXvsbDssD3pQBXA        1050000
#
#   channel_vcount channel_views
# 0             67      28276669
# 1             50        555526
# 2             82      10153417
# 3            194        131771
# 4            239    3494981527
# 5             10          1113
# 6             21         38344
# 7            100      13623202
# 8             78      88115773
# 9            272     440580264

# %%
def video_tables():
  mydb = mysql.connector.connect(host="localhost",user="root",password="Chunnu@123",database="youtube_harvesting_data")
  mycursor=mydb.cursor()
  drop_query = "drop table if exists playlists"
  mycursor.execute(drop_query)


  mydb.commit()

  try:
    create_query='''CREATE TABLE  if not exists videodetails(channel_name VARCHAR(80),videoid VARCHAR(80) PRIMARY KEY,channelid VARCHAR(100),videotitle VARCHAR(255), videdescript TEXT, videopublish VARCHAR(100), videoCaption VARCHAR(80),vTAgs TEXT, videduration TIME, videocomments bigint,videothumb VARCHAR(255),videoLIKEcount bigint, videoVIEWcount bigint)'''
    mycursor.execute(create_query)
    mydb.commit()
  except:
    print("already exist table") 
  video_details=[]
  db=client['youtube_DATA_project']
  newdb=db['channels']
  for vidata in newdb.find({},{"_id":0,"video_details":1}):
    for i in range(len(vidata["video_details"])):
      video_details.append(vidata["video_details"][i])
  df_=pd.DataFrame(video_details)
  for index,row in df_.iterrows():
    insert_query='''insert into videodetails(channel_name, videoid, channelid, videotitle, videdescript, videopublish, videoCaption, vTAgs, videduration, videocomments,videothumb,videoLIKEcount, videoVIEWcount)
    values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
    values=(row['channeltitle'],row['vID'],row['channel_IDS'],row['videotitle'],row['videdescript'],row['videopublish'].replace("T"," ").replace("Z"," "),row['videocaption'],row['vTags'],row['videduration'].replace('PT', ':').replace('H', ':').replace('M', ':').split('S')[0],row['videocommcount'],row['videothumb'],row['videolikecount'],row['videoVIEWcount'])
    try:
      mycursor.execute(insert_query,values)
      mydb.commit() 
    except:
      print("already exists values")

# %%
video_tables()
# Out:
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values
# already exists values

# %%
def comment_table():
  mydb = mysql.connector.connect(host="localhost",user="root",password="Chunnu@123",database="youtube_harvesting_data")
  mycursor=mydb.cursor()
  drop_query = "drop table if exists playlists"
  mycursor.execute(drop_query)
  mydb.commit()
try:
  create_query='''CREATE TABLE  if not exists comments_details(comment_id VARCHAR(100) PRIMARY KEY,video_id VARCHAR(100), comment_text TEXT, comment_author VARCHAR(100), comment_publish VARCHAR(100))'''
  mycursor.execute(create_query)
  mydb.commit()
except:
  print("ALREADY HAS COMMENTS TABLE")
comment_details=[]
db=client['youtube_DATA_project']
newdb=db['channels']
for comm_data in newdb.find({},{"_id":0,"comment_details":1}):
  for i in range(len(comm_data["comment_details"])):
    comment_details.append(comm_data["comment_details"][i])
df2=pd.DataFrame(comment_details)
    
for index,row in df2.iterrows():
    insert_query='''insert into comments_details(comment_id, video_id, comment_text, comment_author, comment_publish)
    values(%s,%s,%s,%s,%s)'''
    values=(row['commid'],row['videoI'],row['commtxt'],row['commauthor'],row['commpublish'].replace("T"," ").replace("Z"," "))
    try:
      mycursor.execute(insert_query,values)
      mydb.commit()
    except:
      print("values of comments exists")
# Out:
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# ...
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists
# values of comments exists

# %%
comment_table()

# %%
def tables():
    channels_table()
    video_tables()
    comment_table()
    return "Tables Created successfully"

# %%
insert=tables

# %%
insert
# Out:
# <function __main__.tables()>

# %%
import streamlit as st

# %%
def view_channel_table():
    channel_list=[]
    db=client['youtube_DATA_project']
    newdb=db['channels']
    for chdata in newdb.find({},{"_id":0,"channel_info":1}):
        channel_list.append(chdata["channel_info"])
    ch_table=st.dataframe(channel_list)
    return ch_table

# %%
view_channel_table()
# Out:
# DeltaGenerator()

# %%
import pandas as pd

# %%
import streamlit as st

# %%
def view_video_table():
  video_details=[]
  db=client['youtube_DATA_project']
  newdb=db['channels']
  for vidata in newdb.find({},{"_id":0,"video_details":1}):
    for i in range(len(vidata["video_details"])):
      video_details.append(vidata["video_details"][i])
  vi_table=st.dataframe(video_details)
  return vi_table

# %%
view_video_table()
# Out:
# 2024-01-01 20:28:19.949 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert '20' with type str: tried to convert to int64", 'Conversion failed for column videolikecount with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# DeltaGenerator()

# %%
def view_comments_table():
    comment_details=[]
    db=client['youtube_DATA_project']
    newdb=db['channels']
    for comm_data in newdb.find({},{"_id":0,"comment_details":1}):
        for i in range(len(comm_data["comment_details"])):
            comment_details.append(comm_data["comment_details"][i])
    comm_table=st.dataframe(comment_details)
    return comm_table

# %%
view_comments_table()
# Out:
# DeltaGenerator()

# %%
with st.sidebar:
    st.title(":green[YOUTUBE DATA HARVESTING PROJECT]")  
    st.header("Skills")
    
ch_ids=st.text_input("type channel id")
channels = ch_ids.split(',')
channels = [ch.strip() for ch in channels if ch]


if st.button("COLLECTION & STORING "):
  for channel in channels:
    ch_list=[]
    db=client['youtube_DATA_project']
    newdb=db['channels']
    for chdata in newdb.find({},{"_id":0,"channel_info":1}):
      ch_list.append(chdata["channel_info"]["channel_ID"])
      if ch_ids in ch_list:
        st.success("channel details already exist")
      else:
        insert= main(ch_ids)
        st.success(insert)

# %%
ch_list=[]
db=client['youtube_DATA_project']
newdb=db['channels']
for chdata in newdb.find({},{"_id":0,"channel_info":1}):
    print(chdata["channel_info"]['channel_ID'])
# Out:
# UC0GGy2O7TE_gyTzyrsN5hYQ
# UC3LD42rjj-Owtxsa6PwGU5Q
# UC3rY5HOgbBvGmq7RnDfwF7A
# UC61Y04JVLkByFRv1K3V-KGQ
# UCJvE3uJFyBS1WhL1Tou85Hg

# %%
if st.button("migrate to SQL"):
  Table=tables()
  st.success(Table)
  
show_table = st.radio("SELECT THE TABLE FOR VIEW",(":green[channels]",":red[videos]",":blue[comments]"))

if show_table == ":green[channels]":
   view_channel_table()

elif show_table ==":red[videos]":
    view_video_table()
elif show_table == ":blue[comments]":
    view_comments_table()

# %%
query2 = "select ch_name as ChannelName, ch_v_count as NO_Videos from channels order by ch_v_count desc;"
mycursor.execute(query2)

t2=mycursor.fetchall()
d=pd.DataFrame(t2, columns=["Channel Name","No Of Videos"])

# %%
d
# Out:
#       Channel Name  No Of Videos
# 0       rjkarishma           239
# 1  Analyst Adithya           194
# 2   Rishabh Mishra            82
# 3    Dadi Ki Rasoi            66
# 4        Streamlit            50

# %%
import pandas as pd

# %%
import streamlit as st

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\dheeraj\anaconda3\lib\site-packages (1.29.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (4.21.12)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (4.7.1)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\dheeraj\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: jinja2 in c:\users\dheeraj\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in c:\users\dheeraj\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\dheeraj\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\dheeraj\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\dheeraj\anaconda3\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dheeraj\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dheeraj\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dheeraj\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dheeraj\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dheeraj\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dheeraj\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dheeraj\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\dheeraj\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\dheeraj\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dheeraj\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
